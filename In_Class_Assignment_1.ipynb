# %% [markdown]
# <a href="https://colab.research.google.com/github/jxd4348/BTE-320-Assignment-1/blob/main/In_Class_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In class Assignment 1, 9/3

# %%
sales = input('Enter Sales: ')
COGS = input("Enter COGS: ")
gross profit = sales - COGS
print(gross profit)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2229992544.py in <cell line: 0>()
# ----> 1 sales = int(input('Enter Sales: '))
#       2 COGS = int(input("Enter COGS: "))
#       3 gross_profit = sales - COGS
#       4 print(gross_profit)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
sales = input('Enter Sales: ')
COGS = input("Enter COGS: ")
gross_profit = sales - COGS
print(gross_profit)
# Out:
# Enter Sales: 300000
# Enter COGS: 12967
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1089330668.py in <cell line: 0>()
#       1 sales = input('Enter Sales: ')
#       2 COGS = input("Enter COGS: ")
# ----> 3 gross_profit = sales - COGS
#       4 print(gross_profit)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
sales = int('Enter Sales: ')
      2 COGS = int("Enter COGS: ")
----> 3 gross_profit = sales - COGS
      4 print(gross_profit)
# Out:
#   File "/tmp/ipython-input-1172989804.py", line 2
#     2 COGS = int("Enter COGS: ")
#     ^
# IndentationError: unexpected indent

# %%
sales = int('Enter Sales: ')
2 COGS = int("Enter COGS: ")
gross_profit = sales - COGS
print(gross_profit)
# Out:
#   File "/tmp/ipython-input-582525378.py", line 2
#     2 COGS = int("Enter COGS: ")
#       ^
# SyntaxError: invalid syntax

# %%
sales = int(input('Enter Sales: '))
COGS = int(input("Enter COGS: "))
gross_profit = sales - COGS
print(gross_profit)
# Out:
# Enter Sales: 200000
# Enter COGS: 12546
# 187454

# %% [markdown]
# Final Code

# %%
sales = input("Enter sales ($): ")
sales = float(sales)

cogs_pct = input("Enter cogs (%)")
cogs_pct = float(cogs_pct)

cogs = sales * (cogs_pct / 100)
grossProfit = sales - cogs
taxes = grossProfit * rate / 100
netIncome = grossProfit - taxes


print(f"cost of Goods sold: ${cogs}")
print(f"Gross Profit: ${grossProfit}")
print(f"Taxes: ${taxes}")
print(f"Net Income: ${netIncome}")

# %% [markdown]
# In class assignment 2, 9/8

# %% [markdown]
# Final code

# %%
import math

d = input("Enter Annual Demand (units/year): ")
d = float(d)

s = input("Enter Reorder cost ($/order): ")
s = float(s)

h = input("Enter holding cost($/unit/year): ")
h = float(h)

EOQ = (2 * d * s / h) ** (1/2)

print(f"annual demand: ${d}")
print(f"Reorder cost: ${s}")
print(f"Holding Cost: ${h}")
print(f"EOQ: ${EOQ}")
# Out:
# Enter Annual Demand (units/year): 30
# Enter Reorder cost ($/order): 50
# Enter holding cost($/unit/year): 20
# annual demand: $30.0
# Reorder cost: $50.0
# Holding Cost: $20.0
# EOQ: $12.24744871391589

# %% [markdown]
# Assignment 3 9/15

# %%
x = input("Enter x: ")
x = float(x)

y = input("Enter y: ")
y = float(y)

z = input("Enter z: ")
z = float(z)

A = x**y + z
print(f"A: {A}")
# Out:
# Enter x: 40
# Enter y: 7
# Enter z: 7
# A: 163840000007.0

# %% [markdown]
# Final code

# %%
x = float(input("Enter x: "))
y = float(input("Enter y: "))
op = input("Enter operator (+, -, *, /, //, **, %): ")

if op == "+":
    result = x + y
elif op == "-":
    result = x - y
elif op == "*":
    result = x * y
elif op == "/":
    result = x / y
elif op == "//":
    result = x // y
elif op == "**":
    result = x ** y
elif op == "%":
    result = x % y
else:
  result = None
  print("Invalid operator")

print(f"result = {result}")
# Out:
# Enter x: 3
# Enter y: 4
# Enter operator (+, -, *, /, //, **, %): **
# result = 81.0

# %% [markdown]
# Assignment 4 9/17

# %%
x = float(input('Enter hours 1-8: '))
range(1, 8)
if x == 1
    result = $7.5
elif x == 2
    result = $10.0
elif x == 3
    result = $12.5
elif x == 4
    result = $15.0
elif x == 5
    result = $17.5
elif x == 6
    result = $20.0
elif x == 7
    result = $22.5
elif x == 8
    result = $25
else:
    result = <$10 OR >$20
    print('invalid charge')

print(f"result = {result}")
# Out:
#   File "/tmp/ipython-input-1352911184.py", line 3
#     if x == 1
#              ^
# SyntaxError: expected ':'

# %% [markdown]
# Final Code

# %%
for hours in range(1,9):
  fee = 5 + 2.5 * hours

  if fee < 10:
    fee = 10.0
  elif fee > 20:
    fee = 20.0

  print(hours, fee)
# Out:
# 1 10.0
# 2 10.0
# 3 12.5
# 4 15.0
# 5 17.5
# 6 20.0
# 7 20.0
# 8 20.0

# %% [markdown]
# Assingment 5 9/22

# %% [markdown]
# Final Code

# %%
print("$Ad, $Profit")
for Ad in range(0, 201, 25):
  revenue = (20 + 2 * Ad **.5) * 10
  cost = 200 + Ad
  profit = revenue - cost
  print(Ad, round(profit, 2))
# Out:
# $Ad, $Profit
# 0 0.0
# 25 75.0
# 50 91.42
# 75 98.21
# 100 100.0
# 125 98.61
# 150 94.95
# 175 89.58
# 200 82.84

# %% [markdown]
# Assignment 6 9/24

# %%
numbers = []
num = float(input("Enter a number: "))

while num != 0:
  numbers.append(num)
  num = float(input("Enter another a number: "))

numbers.sort(reverse=True)
print(numbers)
# Out:
# Enter a number: 3
# Enter another a number: 7
# Enter another a number: 1
# Enter another a number: 2
# Enter another a number: 0
# [7.0, 3.0, 2.0, 1.0]

# %% [markdown]
# Assignment 7 10/1

# %%
#Ai version
import random

# Start the game
print("Welcome to Rock-Paper-Scissors!")

play = input("Do you want to play? (yes/no): ").lower()

while play == "yes":
    # User choice
    user_choice = input("Choose rock, paper, or scissor: ").lower()

    # Computer choice
    computer_choice = random.choice(['rock', 'paper', 'scissor'])
    print(f"Computer chose: {computer_choice}")

    # Determine winner
    if user_choice == computer_choice:
        print("It's a tie!")
    elif (user_choice == "rock" and computer_choice == "scissor") or \
         (user_choice == "paper" and computer_choice == "rock") or \
         (user_choice == "scissor" and computer_choice == "paper"):
        print("You win!")
    else:
        print("Computer wins!")

    # Ask to play again
    play = input("Do you want to play again? (yes/no): ").lower()

print("Thanks for playing!")
# Out:
# Welcome to Rock-Paper-Scissors!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-161200257.py in <cell line: 0>()
#       5 print("Welcome to Rock-Paper-Scissors!")
#       6
# ----> 7 play = input("Do you want to play? (yes/no): ").lower()
#       8
#       9 while play == "yes":
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
#class version
import random

while True:

  play = input('Do you want to play a game? (yes/no): ').strip().lower()

  if play == 'no':
    break

  user_choice = input('Choose rock, paper, or scissor: ').strip().lower()
  pc_choice = random.choice(['rock', 'paper', 'scissor'])
  print(f'Computer chose: {pc_choice}')

  if user_choice == pc_choice:
    print('It\'s a tie!')
  elif (
    (user_choice == 'rock' and pc_choice == 'scissor') or
    (user_choice == 'paper' and pc_choice == 'rock') or
    (user_choice == 'scissor' and pc_choice == 'paper')
    ):
    print('User wins!')
  else:
    print('Computer wins!')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1473364456.py in <cell line: 0>()
#       4 while True:
#       5
# ----> 6   play = input('Do you want to play a game? (yes/no): ').strip().lower()
#       7
#       8   if play == 'no':
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# Assignment 8 10/1

# %%
products = {'P-01': 9.95, 'P-02': 10.50}
print('Enter product number:')
product_number = input()

if product_number == 'P-01':
  print(products['P-01'])
elif product_number == 'P-02':
  print(products['P-02'])
else:
  print('Invalid product number')
# Out:
# Enter product number:
# P-01
# 9.95

# %%
products = {
    'P-01': 9.95,
    'P-02': 10.50
}

id = input('Enter product ID:')

if id in products:
  print(f'{id}: {products[id]}')
else:
  print(f'{id} not found')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2492634075.py in <cell line: 0>()
#       4 }
#       5
# ----> 6 id = input('Enter product ID:')
#       7
#       8 if id in products:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
